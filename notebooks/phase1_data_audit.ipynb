# %% [markdown]
# # 📉 **The Sacking Effect**
#
# ### **Estimating the Causal Impact of Managerial Changes in Football**
#
# ### **Step 1: Test `soccerdata` and Set Up Folders**
#
#
#
#
# ---

# %%
import soccerdata as sd

print("soccerdata works!")

from pathlib import Path

PROJECT_ROOT = Path("..")

RAW_DATA = PROJECT_ROOT / "data" / "raw"
PROCESSED_DATA = PROJECT_ROOT / "data" / "processed"
OUTPUT = PROJECT_ROOT / "output"

RAW_DATA.mkdir(parents=True, exist_ok=True)
PROCESSED_DATA.mkdir(parents=True, exist_ok=True)
OUTPUT.mkdir(parents=True, exist_ok=True)
# Out:
# soccerdata works!

# %% [markdown]
# ### **Step 2: Collect La Liga Schedule**

# %%
import soccerdata as sd

fbref = sd.FBref(
    leagues="ESP-La Liga",
    seasons=["2025-2026"]
)

schedule = fbref.read_schedule().reset_index()

print(schedule.columns.tolist())
print(schedule.head())
# Out:
# [09/03/26 17:06:49] INFO     Saving cached data to C:\Users\anton\soccerdata\data\FBref              ]8;id=15789282;file://C:\Users\anton\AppData\Roaming\Python\Python313\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=15789283;file://C:\Users\anton\AppData\Roaming\Python\Python313\site-packages\soccerdata\_common.py#250\250]8;;\
# ['league', 'season', 'game', 'week', 'day', 'date', 'time', 'home_team', 'score', 'away_team', 'attendance', 'venue', 'referee', 'match_report', 'notes', 'game_id']
#         league season                               game  week  day  \
# 0  ESP-La Liga   2526   2025-08-15 Girona-Rayo Vallecano     1  Fri
# 1  ESP-La Liga   2526       2025-08-15 Villarreal-Oviedo     1  Fri
# 2  ESP-La Liga   2526          2025-08-16 Alavés-Levante     1  Sat
# 3  ESP-La Liga   2526      2025-08-16 Mallorca-Barcelona     1  Sat
# 4  ESP-La Liga   2526  2025-08-16 Valencia-Real Sociedad     1  Sat
#
# ...

# %% [markdown]
# ### **Step 2.1: Inspect Key Teams**

# %%
teams = ["Real Madrid", "Barcelona", "Atlético Madrid"]

team_matches = schedule[
    schedule["home_team"].isin(teams) |
    schedule["away_team"].isin(teams)
]

print(team_matches[[
    "date",
    "home_team",
    "score",
    "away_team",
    "week"
]].head(20))
# Out:
#          date        home_team score        away_team  week
# 3  2025-08-16         Mallorca   0–3        Barcelona     1
# 7  2025-08-17         Espanyol   2–1  Atlético Madrid     1
# 9  2025-08-19      Real Madrid   1–0          Osasuna     1
# 11 2025-08-23  Atlético Madrid   1–1            Elche     2
# 12 2025-08-23          Levante   2–3        Barcelona     2
# 15 2025-08-24           Oviedo   0–3      Real Madrid     2
# 23 2025-08-30           Alavés   1–1  Atlético Madrid     3
# 26 2025-08-30      Real Madrid   2–1         Mallorca     3
# 29 2025-08-31   Rayo Vallecano   1–1        Barcelona     3
# 33 2025-09-13  Atlético Madrid   2–0       Villarreal     4
# 35 2025-09-13    Real Sociedad   1–2      Real Madrid     4
# 36 2025-09-14        Barcelona   6–0         Valencia     4
# 44 2025-09-20      Real Madrid   2–0         Espanyol     5
# 47 2025-09-21        Barcelona   3–0           Getafe     5
# 49 2025-09-21         Mallorca   1–1  Atlético Madrid     5
# ...

# %% [markdown]
# ### **Step 3: Collect Bundesliga Schedule**

# %%
bundesliga = sd.FBref(
    leagues="GER-Bundesliga",
    seasons=["2025-2026"]
)

bundesliga_schedule = bundesliga.read_schedule().reset_index()

print(bundesliga_schedule.columns.tolist())
print(bundesliga_schedule.head())
# Out:
# [09/03/26 17:06:56] INFO     Saving cached data to C:\Users\anton\soccerdata\data\FBref              ]8;id=15789288;file://C:\Users\anton\AppData\Roaming\Python\Python313\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=15789289;file://C:\Users\anton\AppData\Roaming\Python\Python313\site-packages\soccerdata\_common.py#250\250]8;;\
# ['league', 'season', 'game', 'round', 'week', 'day', 'date', 'time', 'home_team', 'score', 'away_team', 'attendance', 'venue', 'referee', 'match_report', 'notes', 'game_id']
#            league season                                 game       round  \
# 0  GER-Bundesliga   2526  2025-08-22 Bayern Munich-RB Leipzig  Bundesliga
# 1  GER-Bundesliga   2526   2025-08-23 Frankfurt-Werder Bremen  Bundesliga
# 2  GER-Bundesliga   2526         2025-08-23 Freiburg-Augsburg  Bundesliga
# 3  GER-Bundesliga   2526      2025-08-23 Heidenheim-Wolfsburg  Bundesliga
# 4  GER-Bundesliga   2526     2025-08-23 Leverkusen-Hoffenheim  Bundesliga
#
# ...

# %% [markdown]
# ### Step 4: Collect Premier League Schedule
#
# Collect the 2025–26 Premier League schedule for Manchester City, Liverpool, and Arsenal.

# %%
premier_league = sd.FBref(
    leagues="ENG-Premier League",
    seasons=["2025-2026"]
)

premier_league_schedule = premier_league.read_schedule().reset_index()

print(premier_league_schedule.columns.tolist())
print(premier_league_schedule.head())
# Out:
# [09/03/26 17:07:01] INFO     Saving cached data to C:\Users\anton\soccerdata\data\FBref              ]8;id=15789294;file://C:\Users\anton\AppData\Roaming\Python\Python313\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=15789295;file://C:\Users\anton\AppData\Roaming\Python\Python313\site-packages\soccerdata\_common.py#250\250]8;;\
# ['league', 'season', 'game', 'week', 'day', 'date', 'time', 'home_team', 'score', 'away_team', 'attendance', 'venue', 'referee', 'match_report', 'notes', 'game_id']
#                league season                              game  week  day  \
# 0  ENG-Premier League   2526  2025-08-15 Liverpool-Bournemouth     1  Fri
# 1  ENG-Premier League   2526  2025-08-16 Aston Villa-Newcastle     1  Sat
# 2  ENG-Premier League   2526        2025-08-16 Brighton-Fulham     1  Sat
# 3  ENG-Premier League   2526    2025-08-16 Sunderland-West Ham     1  Sat
# 4  ENG-Premier League   2526      2025-08-16 Tottenham-Burnley     1  Sat
#
# ...

# %% [markdown]
# ### Step 5: Collect Ligue 1 Schedule
#
# Collect the 2025–26 Ligue 1 schedule to obtain PSG's match data.

# %%
ligue1 = sd.FBref(
    leagues="FRA-Ligue 1",
    seasons=["2025-2026"]
)

ligue1_schedule = ligue1.read_schedule().reset_index()

print(ligue1_schedule.columns.tolist())
print(ligue1_schedule.head())
# Out:
# [09/03/26 17:07:07] INFO     Saving cached data to C:\Users\anton\soccerdata\data\FBref              ]8;id=15789300;file://C:\Users\anton\AppData\Roaming\Python\Python313\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=15789301;file://C:\Users\anton\AppData\Roaming\Python\Python313\site-packages\soccerdata\_common.py#250\250]8;;\
# ['league', 'season', 'game', 'round', 'week', 'day', 'date', 'time', 'home_team', 'score', 'away_team', 'attendance', 'venue', 'referee', 'match_report', 'notes', 'game_id']
#         league season                         game    round  week  day  \
# 0  FRA-Ligue 1   2526  2025-08-15 Rennes-Marseille  Ligue 1     1  Fri
# 1  FRA-Ligue 1   2526         2025-08-16 Lens-Lyon  Ligue 1     1  Sat
# 2  FRA-Ligue 1   2526   2025-08-16 Monaco-Le Havre  Ligue 1     1  Sat
# 3  FRA-Ligue 1   2526     2025-08-16 Nice-Toulouse  Ligue 1     1  Sat
# 4  FRA-Ligue 1   2526   2025-08-17 Angers-Paris FC  Ligue 1     1  Sun
#
# ...

# %% [markdown]
# ### Step 6: Collect Serie A Schedule
#
# Collect the 2025–26 Serie A schedule to obtain Inter Milan's match data.

# %%
serie_a = sd.FBref(
    leagues="ITA-Serie A",
    seasons=["2025-2026"]
)

serie_a_schedule = serie_a.read_schedule().reset_index()

print(serie_a_schedule.columns.tolist())
print(serie_a_schedule.head())
# Out:
# [09/03/26 17:07:11] INFO     Saving cached data to C:\Users\anton\soccerdata\data\FBref              ]8;id=15789306;file://C:\Users\anton\AppData\Roaming\Python\Python313\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=15789307;file://C:\Users\anton\AppData\Roaming\Python\Python313\site-packages\soccerdata\_common.py#250\250]8;;\
# ['league', 'season', 'game', 'week', 'day', 'date', 'time', 'home_team', 'score', 'away_team', 'attendance', 'venue', 'referee', 'match_report', 'notes', 'game_id']
#         league season                        game  week  day       date  \
# 0  ITA-Serie A   2526      2025-08-23 Genoa-Lecce     1  Sat 2025-08-23
# 1  ITA-Serie A   2526  2025-08-23 Milan-Cremonese     1  Sat 2025-08-23
# 2  ITA-Serie A   2526     2025-08-23 Roma-Bologna     1  Sat 2025-08-23
# 3  ITA-Serie A   2526  2025-08-23 Sassuolo-Napoli     1  Sat 2025-08-23
# 4  ITA-Serie A   2526    2025-08-24 Atalanta-Pisa     1  Sun 2025-08-24
#
# ...

# %% [markdown]
# Step 7: Verify the Donor Teams

# %%
print("La Liga teams:")
print(schedule["home_team"].unique())

print("\nBundesliga teams:")
print(bundesliga_schedule["home_team"].unique())

print("\nPremier League teams:")
print(premier_league_schedule["home_team"].unique())

print("\nLigue 1 teams:")
print(ligue1_schedule["home_team"].unique())

print("\nSerie A teams:")
print(serie_a_schedule["home_team"].unique())
# Out:
# La Liga teams:
# <ArrowStringArray>
# [         'Girona',      'Villarreal',          'Alavés',        'Mallorca',
#         'Valencia',   'Athletic Club',      'Celta Vigo',        'Espanyol',
#            'Elche',     'Real Madrid',      'Real Betis', 'Atlético Madrid',
#          'Levante',         'Osasuna',          'Oviedo',   'Real Sociedad',
#          'Sevilla',  'Rayo Vallecano',          'Getafe',       'Barcelona']
# Length: 20, dtype: string
#
# Bundesliga teams:
# <ArrowStringArray>
# ['Bayern Munich',     'Frankfurt',      'Freiburg',    'Heidenheim',
#     'Leverkusen',      'St Pauli',  'Union Berlin',      'Gladbach',
#       'Mainz 05',  'Hamburger SV',      'Augsburg',    'Hoffenheim',
#     'RB Leipzig',     'Stuttgart', 'Werder Bremen',      'Dortmund',
#           'Köln',     'Wolfsburg',  'Paderborn 07']
# Length: 19, dtype: string
#
# Premier League teams:
# <ArrowStringArray>
# [      'Liverpool',     'Aston Villa',        'Brighton',      'Sunderland',
# ...

# %% [markdown]
# ## Step 8: Visualize Results
#
# Plot the rolling 5-match points per game and mark the managerial change date.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import soccerdata as sd

TREATMENT_DATE = pd.Timestamp("2026-01-12")  # Alonso sacked, Arbeloa appointed
TEAMS = ["Real Madrid", "Barcelona", "Atlético Madrid"]
ROLLING_WINDOW = 5  # matches


def pull_la_liga(seasons):
    fbref = sd.FBref(leagues="ESP-La Liga", seasons=seasons)
    return fbref.read_schedule().reset_index()


def parse_score(raw):
   
    if pd.isna(raw):
        return None, None
    parts = str(raw).split("\u2013")
    if len(parts) != 2:
        return None, None
    try:
        return int(parts[0].strip()), int(parts[1].strip())
    except ValueError:
        return None, None


def team_points_series(schedule, team_name):
    """Per-match dataframe of date + matchweek + points earned for one team."""
    home = schedule[schedule["home_team"] == team_name].copy()
    away = schedule[schedule["away_team"] == team_name].copy()

    def pts(row, is_home):
        hs, as_ = parse_score(row["score"])
        if hs is None:
            return None  # not played yet, or unparseable
        if hs == as_:
            return 1
        if is_home:
            return 3 if hs > as_ else 0
        return 3 if as_ > hs else 0

    home["points"] = home.apply(lambda r: pts(r, True), axis=1)
    away["points"] = away.apply(lambda r: pts(r, False), axis=1)

    both = pd.concat([home, away])[["date", "week", "points"]].dropna(subset=["points"])
    both["date"] = pd.to_datetime(both["date"])
    both = both.sort_values("date").reset_index(drop=True)
    both["team"] = team_name
    both["rolling_ppg"] = both["points"].rolling(ROLLING_WINDOW, min_periods=1).mean()
    return both


def main():
    schedule = pull_la_liga(seasons=["2025-2026"])
    schedule.to_csv(RAW_DATA / "la_liga_2025_2026_schedule.csv", index=False)

    all_teams = pd.concat([team_points_series(schedule, t) for t in TEAMS])
    all_teams.to_csv(PROCESSED_DATA / "team_rolling_ppg.csv", index=False)

    fig, ax = plt.subplots(figsize=(10, 6))
    for team in TEAMS:
        sub = all_teams[all_teams["team"] == team]
        ax.plot(sub["date"], sub["rolling_ppg"], label=team, linewidth=2)

    ax.axvline(TREATMENT_DATE, color="gray", linestyle="--", linewidth=1)
    ax.text(TREATMENT_DATE, ax.get_ylim()[1], "Alonso sacked", rotation=90,
            va="top", ha="right", fontsize=9, color="gray")
    ax.set_ylabel(f"Rolling {ROLLING_WINDOW}-match points per game")
    ax.set_title("Real Madrid vs. comparison clubs, 2025-26 La Liga")
    ax.legend()
    fig.tight_layout()
    fig.savefig(OUTPUT / "real_madrid_ppg_sanity_check.png", dpi=150)

    print("Saved: la_liga_2025_2026_schedule.csv, team_rolling_ppg.csv, "
          "real_madrid_ppg_sanity_check.png")


if __name__ == "__main__":
    main()
# Out:
# [09/03/26 17:07:25] INFO     Saving cached data to C:\Users\anton\soccerdata\data\FBref              ]8;id=15789312;file://C:\Users\anton\AppData\Roaming\Python\Python313\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=15789313;file://C:\Users\anton\AppData\Roaming\Python\Python313\site-packages\soccerdata\_common.py#250\250]8;;\
# Saved: la_liga_2025_2026_schedule.csv, team_rolling_ppg.csv, real_madrid_ppg_sanity_check.png
